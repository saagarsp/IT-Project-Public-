# %% [markdown]
# <a href="https://colab.research.google.com/github/saagarsp/IT-Project-Public-/blob/master/Mid_Eval.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def show_images(images, cmap=None):
    cols = 2
    rows = (len(images)+1)//cols
    
    plt.figure(figsize=(25, 20))
    for i, image in enumerate(images):
        plt.subplot(rows, cols, i+1)
        # use gray scale color map if there is only one channel
        cmap = 'gray' if len(image.shape)==2 else cmap
        plt.imshow(image, cmap=cmap)
        plt.xticks([])
        plt.yticks([])
    plt.tight_layout(pad=0, h_pad=0, w_pad=0)
    plt.show()

# %%
img=cv2.imread("input.png",0)
show_images([img])

# %%
img.shape
# Out:
# (716, 707)

# %%
plt.figure(figsize=(9,9))
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.show()

# %%
blurImg = cv2.GaussianBlur(img, (3,3), 0)
plt.figure(figsize=(9,9))
plt.imshow(cv2.cvtColor(blurImg,cv2.COLOR_BGR2RGB))
plt.show()

# %%
edged = cv2.Canny(blurImg,50,150,apertureSize=7)
plt.figure(figsize=(9,9))
plt.imshow(cv2.cvtColor(edged,cv2.COLOR_BGR2RGB))
plt.show()

# %%
edged = cv2.Canny(blurImg,50,150,apertureSize=5)
plt.figure(figsize=(9,9))
plt.imshow(cv2.cvtColor(edged,cv2.COLOR_BGR2RGB))
plt.show()

# %%
edged = cv2.Canny(blurImg,50,150,apertureSize=5)
show_images([edged])

# %%
parkImg=cv2.imread("full-parking-lot.png",0)
parkblurImg = cv2.GaussianBlur(parkImg, (3,3), 0)
parkedged = cv2.Canny(parkblurImg,50,150,apertureSize=5)

show_images([parkedged])

# %%
difference = cv2.subtract(edged, parkedged)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c3e5876a9135> in <module>()
# ----> 1 difference = cv2.subtract(edged, parkedged)
#
# NameError: name 'edged' is not defined

# %% [markdown]
# # New Section
